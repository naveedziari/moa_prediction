# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
training_loss = np.load('training_loss.npy')
val_loss = np.load('val_loss.npy')

# %%
epochs = np.linspace(4,16,13)
plt.plot(epochs,training_loss[1,3:],label = 'training')
plt.plot(epochs,val_loss[1,3:], label = 'validation')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.title('Initial Parameters')
plt.savefig('initial_loss_plot.png')

# %%
epochs = np.linspace(1,16,16)

plt.plot(epochs,training_loss_2[1,:],label = 'training')
plt.plot(epochs,val_loss_2[1,:], label = 'validation')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.title('Adjusted Learning Rate')
plt.savefig('adjusted_loss_plot.png')

# %%
epochs = np.linspace(8,32,24)

plt.plot(epochs,training_loss_3[1,8:],label = 'training')
plt.plot(epochs,val_loss_3[1,8:], label = 'validation')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.title('Increased Model Complexity')
plt.savefig('overfit_loss_plot.png')

# %%
epochs = np.linspace(4,16,12)

plt.plot(epochs,training_loss_4[3,4:],label = 'training')
plt.plot(epochs,val_loss_4[3,4:], label = 'validation')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.title('Bayesian Hyperparameter Optimization')
plt.savefig('bayesian_plot.png')

# %%
epochs = np.linspace(6,16,10)

training_loss_5 = np.load('training_loss_5-2.npy')
val_loss_5 = np.load('val_loss_5-2.npy')

plt.plot(epochs,training_loss_5[3,6:],label = 'training')
plt.plot(epochs,val_loss_5[3,6:], label = 'validation')
plt.grid()
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend()
plt.title('Bayesian Hyperparameter Optimization')
plt.savefig('bayesian_plot.png')
